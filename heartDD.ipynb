# %%
import pandas as pd

# %%
df=pd.read_csv('heart_disease_uci.csv')

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.drop(['id','dataset','fbs','exang','oldpeak','slope'],axis=1,inplace=True)

# %%
df
# Out:
#      age     sex               cp  trestbps   chol           restecg  thalch  \
# 0     63    Male   typical angina     145.0  233.0    lv hypertrophy   150.0
# 1     67    Male     asymptomatic     160.0  286.0    lv hypertrophy   108.0
# 2     67    Male     asymptomatic     120.0  229.0    lv hypertrophy   129.0
# 3     37    Male      non-anginal     130.0  250.0            normal   187.0
# 4     41  Female  atypical angina     130.0  204.0    lv hypertrophy   172.0
# ..   ...     ...              ...       ...    ...               ...     ...
# 915   54  Female     asymptomatic     127.0  333.0  st-t abnormality   154.0
# 916   62    Male   typical angina       NaN  139.0  st-t abnormality     NaN
# 917   55    Male     asymptomatic     122.0  223.0  st-t abnormality   100.0
# 918   58    Male     asymptomatic       NaN  385.0    lv hypertrophy     NaN
# 919   62    Male  atypical angina     120.0  254.0    lv hypertrophy    93.0
#
#       ca               thal  num
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    int64
#  1   sex       920 non-null    object
#  2   cp        920 non-null    object
#  3   trestbps  861 non-null    float64
#  4   chol      890 non-null    float64
#  5   restecg   918 non-null    object
#  6   thalch    865 non-null    float64
#  7   ca        309 non-null    float64
#  8   thal      434 non-null    object
#  9   num       920 non-null    int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 72.0+ KB

# %%
df['trestbps'] = df['trestbps'].fillna(df['trestbps'].mean())

# %%
df['chol'] = df['chol'].fillna(df['chol'].mean())

df['thalch'] = df['thalch'].fillna(df['thalch'].mean())
df['ca'] = df['ca'].fillna(df['ca'].mean())

# %%
df
# Out:
#      age     sex               cp    trestbps   chol           restecg  \
# 0     63    Male   typical angina  145.000000  233.0    lv hypertrophy
# 1     67    Male     asymptomatic  160.000000  286.0    lv hypertrophy
# 2     67    Male     asymptomatic  120.000000  229.0    lv hypertrophy
# 3     37    Male      non-anginal  130.000000  250.0            normal
# 4     41  Female  atypical angina  130.000000  204.0    lv hypertrophy
# ..   ...     ...              ...         ...    ...               ...
# 915   54  Female     asymptomatic  127.000000  333.0  st-t abnormality
# 916   62    Male   typical angina  132.132404  139.0  st-t abnormality
# 917   55    Male     asymptomatic  122.000000  223.0  st-t abnormality
# 918   58    Male     asymptomatic  132.132404  385.0    lv hypertrophy
# 919   62    Male  atypical angina  120.000000  254.0    lv hypertrophy
#
#          thalch        ca               thal  num
# 0    150.000000  0.000000       fixed defect    0
# ...

# %%
df4=pd.DataFrame(pd.get_dummies(df['sex']))
df5=pd.DataFrame(pd.get_dummies(df['cp']))
df6=pd.DataFrame(pd.get_dummies(df['thal']))

# %%
df = pd.concat([df4, df], axis=1)
df = pd.concat([df5, df], axis=1)
df = pd.concat([df6, df], axis=1)

# %%
df
# Out:
#      fixed defect  normal  reversable defect  asymptomatic  atypical angina  \
# 0               1       0                  0             0                0
# 1               0       1                  0             1                0
# 2               0       0                  1             1                0
# 3               0       1                  0             0                0
# 4               0       1                  0             0                1
# ..            ...     ...                ...           ...              ...
# 915             0       0                  0             1                0
# 916             0       0                  0             0                0
# 917             1       0                  0             1                0
# 918             0       0                  0             1                0
# 919             0       0                  0             0                1
#
# ...

# %%
df.drop(['sex','cp','restecg','thal'],axis=1,inplace=True)

# %%
df
# Out:
#      fixed defect  normal  reversable defect  asymptomatic  atypical angina  \
# 0               1       0                  0             0                0
# 1               0       1                  0             1                0
# 2               0       0                  1             1                0
# 3               0       1                  0             0                0
# 4               0       1                  0             0                1
# ..            ...     ...                ...           ...              ...
# 915             0       0                  0             1                0
# 916             0       0                  0             0                0
# 917             1       0                  0             1                0
# 918             0       0                  0             1                0
# 919             0       0                  0             0                1
#
# ...

# %%
df['num']
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
#       ..
# 915    1
# 916    0
# 917    2
# 918    0
# 919    1
# Name: num, Length: 920, dtype: int64

# %%
df['num']=pd.cut(df['num'],3, labels=["low", "medium", "high"])

# %%
df6=pd.DataFrame(pd.get_dummies(df['num']))

# %%
df
# Out:
#      fixed defect  normal  reversable defect  asymptomatic  atypical angina  \
# 0               1       0                  0             0                0
# 1               0       1                  0             1                0
# 2               0       0                  1             1                0
# 3               0       1                  0             0                0
# 4               0       1                  0             0                1
# ..            ...     ...                ...           ...              ...
# 915             0       0                  0             1                0
# 916             0       0                  0             0                0
# 917             1       0                  0             1                0
# 918             0       0                  0             1                0
# 919             0       0                  0             0                1
#
# ...

# %%
df = pd.concat([df6, df], axis=1)

# %%
df.drop('num',axis=1,inplace=True)

# %%
df
# Out:
#      low  medium  high  fixed defect  normal  reversable defect  asymptomatic  \
# 0      1       0     0             1       0                  0             0
# 1      0       1     0             0       1                  0             1
# 2      1       0     0             0       0                  1             1
# 3      1       0     0             0       1                  0             0
# 4      1       0     0             0       1                  0             0
# ..   ...     ...   ...           ...     ...                ...           ...
# 915    1       0     0             0       0                  0             1
# 916    1       0     0             0       0                  0             0
# 917    0       1     0             1       0                  0             1
# 918    1       0     0             0       0                  0             1
# 919    1       0     0             0       0                  0             0
#
# ...

# %%
df1=df.iloc[0:800]

# %%
df2=df.iloc[800:920]

# %%
df2
# Out:
#      low  medium  high  fixed defect  normal  reversable defect  asymptomatic  \
# 800    1       0     0             0       0                  0             1
# 801    0       1     0             0       0                  0             1
# 802    0       1     0             0       0                  0             1
# 803    0       1     0             0       0                  0             1
# 804    0       0     1             0       0                  0             1
# ..   ...     ...   ...           ...     ...                ...           ...
# 915    1       0     0             0       0                  0             1
# 916    1       0     0             0       0                  0             0
# 917    0       1     0             1       0                  0             1
# 918    1       0     0             0       0                  0             1
# 919    1       0     0             0       0                  0             0
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=30)
model.fit(a, b)
# Out:
# RandomForestClassifier(n_estimators=30)

# %%
model.fit(a,b)
# Out:
# RandomForestClassifier(n_estimators=30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   low                920 non-null    uint8
#  1   medium             920 non-null    uint8
#  2   high               920 non-null    uint8
#  3   fixed defect       920 non-null    uint8
#  4   normal             920 non-null    uint8
#  5   reversable defect  920 non-null    uint8
#  6   asymptomatic       920 non-null    uint8
#  7   atypical angina    920 non-null    uint8
#  8   non-anginal        920 non-null    uint8
#  9   typical angina     920 non-null    uint8
#  10  Female             920 non-null    uint8
#  11  Male               920 non-null    uint8
#  12  age                920 non-null    int64
#  13  trestbps           920 non-null    float64
#  14  chol               920 non-null    float64
#  15  thalch             920 non-null    float64
# ...

# %%
model.score(a,b)
# Out:
# 0.9978260869565218

# %%
n=df.iloc[:,0:800]
n=df.drop(['low','medium','high'],axis=1)

# %%
n
# Out:
#      fixed defect  normal  reversable defect  asymptomatic  atypical angina  \
# 0               1       0                  0             0                0
# 1               0       1                  0             1                0
# 2               0       0                  1             1                0
# 3               0       1                  0             0                0
# 4               0       1                  0             0                1
# ..            ...     ...                ...           ...              ...
# 915             0       0                  0             1                0
# 916             0       0                  0             0                0
# 917             1       0                  0             1                0
# 918             0       0                  0             1                0
# 919             0       0                  0             0                1
#
# ...

# %%
a =df1.drop(['low','medium','high'], axis=1)
b = df1.filter(['low','medium','high'], axis=1)

# %%
b
# Out:
#      low  medium  high
# 0      1       0     0
# 1      0       1     0
# 2      1       0     0
# 3      1       0     0
# 4      1       0     0
# ..   ...     ...   ...
# 795    1       0     0
# 796    0       1     0
# 797    0       0     1
# 798    0       1     0
# 799    1       0     0
#
# [800 rows x 3 columns]

# %%
a
# Out:
#      fixed defect  normal  reversable defect  asymptomatic  atypical angina  \
# 0               1       0                  0             0                0
# 1               0       1                  0             1                0
# 2               0       0                  1             1                0
# 3               0       1                  0             0                0
# 4               0       1                  0             0                1
# ..            ...     ...                ...           ...              ...
# 795             0       0                  1             1                0
# 796             0       0                  0             0                0
# 797             0       0                  0             0                0
# 798             0       0                  0             1                0
# 799             0       0                  1             1                0
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=30)
model.fit(a, b)
# Out:
# RandomForestClassifier(n_estimators=30)

# %%
model.score(a,b)
# Out:
# 0.99375

# %%
model.predict([[0,0,0,1,0,0,0,1,0,54,127,333,154,0.676]])
# Out:
# E:\AI programs\anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([[1, 0, 0]], dtype=uint8)

# %%
df2
# Out:
#      low  medium  high  fixed defect  normal  reversable defect  asymptomatic  \
# 800    1       0     0             0       0                  0             1
# 801    0       1     0             0       0                  0             1
# 802    0       1     0             0       0                  0             1
# 803    0       1     0             0       0                  0             1
# 804    0       0     1             0       0                  0             1
# ..   ...     ...   ...           ...     ...                ...           ...
# 915    1       0     0             0       0                  0             1
# 916    1       0     0             0       0                  0             0
# 917    0       1     0             1       0                  0             1
# 918    1       0     0             0       0                  0             1
# 919    1       0     0             0       0                  0             0
#
# ...

# %%
import pickle
heart_model = pickle.dumps(model)

# %%
heartmodel = pickle.loads(heart_model)
heartmodel.predict([[0,0,0,1,0,0,0,1,0,54,127,333,154,0.676]])
# Out:
# E:\AI programs\anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([[1, 0, 0]], dtype=uint8)
